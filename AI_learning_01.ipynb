# %% [markdown]
# <a href="https://colab.research.google.com/github/HH-Wang-HH/Example_Learning-GitHub/blob/develop/AI_learning_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df_housing = pd.read_csv("https://raw.githubusercontent.com/huangjia2019/house/master/house.csv")
X=df_housing.drop("median_house_value", axis=1)
y=df_housing.median_house_value
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
from sklearn.linear_model import LinearRegression
model= LinearRegression()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
print ('房價真值(測試集)\n', y_test)
print ('預測房價(測試集)\n', y_pred)
print ('評分', model.score(X_test, y_test))
# Out:
# 房價真值(測試集)
#  3873     171400.0
# 3625     189600.0
# 3028     500001.0
# 13814    229400.0
# 15398    163400.0
#            ...
# 1363     212500.0
# 7947     210500.0
# 14574    142900.0
# 10009    128300.0
# 9149      84700.0
# Name: median_house_value, Length: 3400, dtype: float64
# 預測房價(測試集)
#  [211157.06335417 218581.64298574 465317.31295563 ... 201751.23969631
#  160873.51846958 138847.26913352]
# 評分 0.632101417157948
